# %% [markdown]
# # Exploratory Data Analysis on Retail Store Dataset

# %% [markdown]
# ## Author-Shreeya Parikh

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
data=pd.read_csv(r"C:\Users\Admin\OneDrive\SampleSuperstore.csv")

# %% [markdown]
# ## Understanding the data

# %%
data
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
##To view the first 5 rows of the data
data.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
## To view last 5 rows of the data
data.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
data.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount      Profit
# count   9977.000000   9977.000000  9977.000000  9977.000000  9977.00000
# mean   55154.964117    230.148902     3.790719     0.156278    28.69013
# std    32058.266816    623.721409     2.226657     0.206455   234.45784
# min     1040.000000      0.444000     1.000000     0.000000 -6599.97800
# 25%    23223.000000     17.300000     2.000000     0.000000     1.72620
# 50%    55901.000000     54.816000     3.000000     0.200000     8.67100
# 75%    90008.000000    209.970000     5.000000     0.200000    29.37200
# max    99301.000000  22638.480000    14.000000     0.800000  8399.97600

# %%
#Shows the number of rows and columns
data.shape
# Out:
# (9994, 13)

# %%
#shows the information about the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
## shows the columns names
data.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %% [markdown]
# ## Finding Missing Values

# %%
#checking for null values 
data.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# ## Checking and removing duplicate values

# %%
data.duplicated().sum()
# Out:
# 17

# %%
data.drop_duplicates()
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# # Analyzing the data

# %%
## shows the correlation between each measure value in the dataset
data.corr()
plt.figure(figsize=(10,7))
sns.heatmap(data.corr(), annot=True)
plt.show()

# %% [markdown]
# ## Analyzing profits and sales acquired by each ship mode

# %%
ship_mode=data.groupby(data['Ship Mode']).Profit.sum()
ship_mode
# Out:
# Ship Mode
# First Class        48969.8399
# Same Day           15891.7589
# Second Class       57446.6354
# Standard Class    164088.7875
# Name: Profit, dtype: float64

# %%
ship_mode_sales=data.groupby(data['Ship Mode']).Sales.max()
ship_mode_sales
# Out:
# Ship Mode
# First Class       13999.96
# Same Day           7999.98
# Second Class       8749.95
# Standard Class    22638.48
# Name: Sales, dtype: float64

# %% [markdown]
# ## Visualizing the profits generated by each ship mode

# %%
ship_mode=data.groupby(data['Ship Mode']).Profit.sum().plot.bar(xlabel='Ship Mode', ylabel='Total Profits Generated',title='Profits generated by Ship Mode')

# %% [markdown]
# ### We can clearly see that the Standard Class has acquired the maximum profits in comparison to other ship modes and the Same Day ship mode has generated the lowest profits

# %% [markdown]
# ## Visualizing the total sales generated by ship modes

# %%
ship_mode_sales=data.groupby(data['Ship Mode']).Sales.sum().plot.bar(title='Total Sales genereated by each ship mode',ylabel='Sales',color='g',figsize=(9,6))

# %% [markdown]
# ### We can see that the First Class and Second Class ship modes have nearly equal amount of sales to each other and Standard class is yet again highest in sales.

# %%
sales = data.groupby('Ship Mode').Sales.sum()
profit = data.groupby('Ship Mode').Profit.sum()
sales.plot.bar()
profit.plot.bar(color='r',figsize=(8,9))
plt.xlabel('Ship Mode')
plt.ylabel('Sales & Profits')
plt.title('Sales and Profits generated by each Ship Mode')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ### This graph shows both sales and profits w.r.t. Ship Mode.It can be clearly seen that the customers prefer the Standard class more and hence, it generates profits accordingly.

# %% [markdown]
# ## Min. Profit earned

# %%
#visualizing the mimimum profit gained by each shipmode
ship_mode_avg=data.groupby(data['Ship Mode']).Profit.min().plot.bar(figsize=(12,5),color='g')

# %% [markdown]
# ## Average Profit gained by each ship modes

# %%
ship_mode_avg=data.groupby(data['Ship Mode']).Profit.mean().plot.bar(figsize=(12,5),color='y',title='Average Profit generated by ship modes')
# All the ship modes have nearly equal average profits to each other.

# %% [markdown]
# ## Customer Segmentwise Profits in Each Category of Product

# %%
##finding out how each category performed w.r.t. profits generated by each segment
customer_seg=data.groupby(['Segment','Category']).Profit.sum()
customer_seg
# Out:
# Segment      Category
# Consumer     Furniture           6991.0786
#              Office Supplies    56330.3210
#              Technology         70797.8096
# Corporate    Furniture           7584.8158
#              Office Supplies    40227.3202
#              Technology         44166.9980
# Home Office  Furniture           3875.3784
#              Office Supplies    25933.1596
#              Technology         30490.1405
# Name: Profit, dtype: float64

# %%
plt.figure(figsize=(10,8))
figure=sns.barplot(x='Category',y='Profit',hue='Segment',data=data,color='g')

# %% [markdown]
# ### It can be clearly analyzed that the Technology category has earned the maximum profits in all the customer segments, while the Furniture category has earned the least profits. Home Office customer segments earns maximum profits in comparison to other segments except in Furniture Category where the Corporate customer segment was the highest

# %%
plt.figure(figsize=(10,6))
figure=sns.barplot(x='Category',y='Sales',hue='Segment',data=data,color='g')

# %% [markdown]
# ### The graph shows that the maximum sales were done by the Technology Category but the Furniture Category was not too far from it, it had good amount of sales completed hence, it can be infered by looking at the above 2 graphs that the Furniture Category is clearly generating losses for the company because it cannot generate profits even after having good sales.

# %%
plt.figure(figsize=(5,8))
sns.barplot(x="Segment",y="Sales",data=data)
plt.title("Sales in Different Segment")
plt.show()

# %% [markdown]
# ### The sales of all the segments are nearly equal to each other.

# %%
plt.figure(figsize=(6,8))
sns.barplot(x="Segment",y="Profit",data=data)
plt.title("Profit in Different Segment")
plt.show()

# %%
sales = data.groupby("Segment").Sales.sum()
profit = data.groupby("Segment").Profit.sum()
sales.plot.bar(color='blue',label='Sales')
profit.plot.bar(color='red',label='Profits')
plt.legend()
plt.xlabel('Category')
plt.ylabel('Sales & Profits')
plt.title("Sales vs Profit")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ### This graph shows the amalgamation of the above 2 graphs. It shows the sales and profits generated by each Customer Segment.

# %%
sales_subcat= data.groupby("Sub-Category").Sales.sum()
profit_subcat = data.groupby("Sub-Category").Profit.sum()
sales.plot.line(label='Sales')
profit.plot.line(color='red',label='Profit')
plt.legend()
plt.xlabel('Sub-Category')
plt.ylabel('Sales & Profits')
plt.title("Sales vs Profit")
plt.xticks(rotation=0)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.barplot(x="Category",y="Profit",data=data,hue="Ship Mode",ci=0)
plt.title("Categories wise profit in different Shipmode")
# Out:
# Text(0.5, 1.0, 'Categories wise profit in different Shipmode')

# %% [markdown]
# ### It can be infered that Technology in First Class ship mode has earned the maximum profits and the least in Second class. The furniture category has the generate the least profits overall and Same Day ship mode has generated the lowest with Second class generating highest profits in the category. In the Office supplies category all the ship modes have nearly equal profits to each other except the Second class ship mode generating the highest profit in the category.

# %%
plt.figure(figsize=(12,8))
sns.barplot(x="Category",y="Sales",data=data,hue="Ship Mode")
plt.title("Categories wise sales in different Shipmode")
# Out:
# Text(0.5, 1.0, 'Categories wise sales in different Shipmode')

# %% [markdown]
# ### The Technology category has been the most preferred category by the customers and Same Day delivery ship mode in the same category has the maximum sales. While the Office supplies category has lowest sales but good enough profits as we saw in the earlier graph, it means the company could focus on this section more.

# %%
cat1=data.groupby(data['Category']).Profit.sum().plot.bar(color='g',ylabel='Total Profit',figsize=(6,5))

# %%
plt.figure(figsize=(5,6))
figure=sns.barplot(x='Category',y='Profit',data=data,color='b')

# %% [markdown]
# ## Sub-categorywise Sales and Profits

# %%
plt.figure(figsize=(17,5))
fig=sns.barplot(x='Sub-Category',y='Sales',data=data)

# %% [markdown]
# ### Copiers have generated the maximum sales and Fasteners have geneated the least sales,while Bookcases and Chairs have generated nearly equal sales to each other.

# %%
sub_sales=data.groupby(data['Sub-Category']).Sales.sum().plot.bar(ylabel='Sales',color='g',figsize=(10,8))

# %%
sub_profit=data.groupby(data['Sub-Category']).Profit.sum().plot.bar(color='g',figsize=(10,8),ylabel='Profit',title='Total Profit generated by each Sub-category')

# %% [markdown]
# ### We can clearly infer from the graph that the categories Tables,Supplies and Bookcases are generating losses for the company while Copiers are generating the maximum profit for the business.

# %% [markdown]
# ## Profitable Regions in the Country

# %%
data.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
## finding which region has generated the maximum profit
Reg=data.groupby(data['Region']).Profit.sum()
Reg
# Out:
# Region
# Central     39706.3625
# East        91522.7800
# South       46749.4303
# West       108418.4489
# Name: Profit, dtype: float64

# %%
Reg=data.groupby(data['Region']).Profit.sum().plot.pie(autopct="%0.2f%%",figsize=(7,10),shadow=True,title='Regionwise Profits')

# %% [markdown]
# ### It can be clearly infered that the West region is the most profitable region while the Central region is the least profitable region.

# %% [markdown]
# ## Total Sales Regionwise

# %%
plt.figure(figsize=(15,8))
plt.pie(data['Sales'].groupby(data.Region).sum(),labels=data['Sales'].groupby(data.Region).sum().index,shadow=True,autopct="%0.2f%%")
plt.title("Region Wise Sales")
plt.show()

# %% [markdown]
# ### We can see that the West region has many sales hence mauy customers from the West region while the South region has the least customers

# %% [markdown]
# ## Regionwise Categorywise Profits and Sales

# %%
plt.figure(figsize=[12,6])
fig=sns.barplot(x='Category',y='Profit',hue='Region',data=data)

# %% [markdown]
# ### As we can see that Technology category is giving good profits in all regions and maximum in East Region. Office Supplies Category is not doing well in Central region than other regions. Furniture category is generating the lowest profits in all regions and generating losses in the central region.

# %%
plt.figure(figsize=[12,6])
fig=sns.barplot(x='Category',y='Sales',hue='Region',data=data)

# %% [markdown]
# ### Technology sector is the most demanded entity and generates maximum sales in the South region,while the Central region is generating the least.Office Supplies category is generating the least sales overall and all the regions have nearly equal sales and demand for office supplies.

# %% [markdown]
# ## Regionwise Profits and sales in sub-categories

# %%
plt.figure(figsize=[24,6])
fig=sns.barplot(x='Sub-Category',y='Sales',hue='Region',data=data)

# %%
plt.figure(figsize=[16,8])
fig=sns.barplot(x='Sub-Category',y='Profit',hue='Region',data=data)

# %% [markdown]
# ## Most Profitable States and it's Sales

# %%
Cit=data.groupby(data['State']).Profit.sum()
Cit
# Out:
# State
# Alabama                  5786.8253
# Arizona                 -3427.9246
# Arkansas                 4008.6871
# California              76381.3871
# Colorado                -6527.8579
# Connecticut              3511.4918
# Delaware                 9977.3748
# District of Columbia     1059.5893
# Florida                 -3399.3017
# Georgia                 16250.0433
# Idaho                     826.7231
# Illinois               -12607.8870
# Indiana                 18382.9363
# Iowa                     1183.8119
# Kansas                    836.4435
# Kentucky                11199.6966
# Louisiana                2196.1023
# Maine                     454.4862
# Maryland                 7031.1788
# Massachusetts            6785.5016
# Michigan                24463.1876
# Minnesota               10823.1874
# Mississippi              3172.9762
# Missouri                 6436.2105
# Montana                  1833.3285
# Nebraska                 2037.0942
# ...

# %%
sales_profit =data.groupby('State').Profit.sum().plot.bar(figsize=(16,9),color='g',ylabel='Profits',title='Profits generated by each state')

# %% [markdown]
# ### New York and California have the maximum profits generated while states like south dakota,north dakota and maine have negligible profits generated. It can also be infered that Texas,Pennsylvania,Ohio,Tennessee,North Carolina,Illinios,Colorado,Arizona are generating losses for the company,with Texas being the highest contributer.

# %%
sales_city=data.groupby('State').Sales.sum().plot.bar(color='g',ylabel='Sales',title='Sales generated by states',figsize=(15,8))

# %% [markdown]
# ### California and New York has the maximum sales acquired from the company while West Virginia, South Dakota,Maine have low sales.

# %%
sales_city=data.groupby('State').Discount.sum().plot.bar(color='g',ylabel='Discount',title='Discount rates given to states',figsize=(15,8))

# %% [markdown]
# ### Texas is given the highest discounts by the company, while many of the states have negligible or no discounts offered as shwon in the graph above.

# %% [markdown]
# ### Relation between Profits generated and Discounts offered

# %%
plt.figure(figsize = (10,6))
sns.lineplot(x='Discount',y='Profit', data=data,label= 'Discount',color='r')
plt.title("Profit vs Discount")
plt.legend()

# %% [markdown]
# ### Discount given on each sub-category of products

# %%
sub=data.groupby(data['Sub-Category']).Discount.sum().plot.bar(ylabel='Discount',title='Discounts offered on each sub-cat')

# %% [markdown]
# ## Discount offered to each customer segment

# %%
con=data.groupby(data['Segment']).Discount.sum().plot.bar(color='b',ylabel='Discount',title='Discount given to each customer segment')

# %% [markdown]
# ### The maximum discount is given to the consumer customer segment,while the least is given to the Home office customer segment.

# %% [markdown]
# ## Discount given to each category of products

# %%
fur=data.groupby(data['Category']).Discount.sum().plot.bar(ylabel='Discount',title='Discount offered to each category of products')

# %% [markdown]
# ### It is infered from the graph that the Office Supplies category is getting the maximum discount from the store while the Technology is getting the least amount of discount from the store.

# %% [markdown]
# ## Profits generated by cities

# %%
fur=data.groupby(data['City']).Profit.sum()[:90].sort_values(ascending=False).plot.bar(ylabel='Profit',title='Profits generated by cities',figsize=(20,9))

# %% [markdown]
# ### Atlanta is the most profitable city in the country, whereas Chicago is the least profitable city in the country.

# %%
fur=data.groupby(data['City']).Sales.sum()[:90].sort_values(ascending=False).plot.bar(ylabel='Sales',title='Sales by cities',figsize=(20,9))

# %% [markdown]
# ### It is surprising to see that the maximum sales generated to the company is from Chicago which is the least profitable city in the country.

# %% [markdown]
# ## Conclusion And Inferences

# %% [markdown]
# 1. Furniture Category has the second highest sales acquired but generates the least amount of profits. This category is also provided with the maximum discount by the company to the consumers which is generating losses for the store. The company could generate more profits from this catefory either by lowering the discounts in this category so the cost price can be much more than the selling price of the commodity or either by stopping the production of such commodities in certain regions.
# 2. The office supplies category is sold maximum in the corporate sector, but is generating maximum profits in the home office customer segment, so the store could focus on increasing the sales by marketing strategies to acquire home office customers.
# 3. Technology category is generating the maximum profits in the store, so the store could focus more on Technology sector rather than Furniture sector to maximize it's profits.
# 4. The sales of the products are nearly equally distributed between the different customer segments but in term of profits, home office customer segment is generating the maximum profit and the consumer customer segment is generating the least amount of profits, provided the discount given to consumer customer segment is also the maximum, hence, the discount percentage needs to be lowered in this customer segment and the home office customers needs to targeted and persuaded by marketing stratergies,offers and discounts to acquire more sales from them.
# 5. Technology category is generating the most profts when shiped by First class ship mode but the sales of the same is less compared to the profits generated, so the company should offer more first class shipping mode to the customers to increase the sales. While the Sales day shipping mode is having maximum sales in Technology sector by second highest profits, this is an area where the company could look into.
# 6. Bookcases,Suppliers,Tables are generating losses for the company and Fastners are generating negligible profits for the company, while the sales for all these are high, the company needs to seriously look into these products, they should discontinue these products and focus more on other products that are generating profits for the company.
# 7. The Furniture category is doing poorly in the Central region of the country and generating losses, so it would be best for the company to discontinue furniture in the central region and focus on generating profits by other products in the region.
# 8. Office supplies in the entire country is uniformly acquired by the customers, but the central region is generating the least amount of profits, so the company could lower the discount ranges in this region to maximize their profits.
# 9. Machines have the maximum sales done, but it isn't generating profits as expected, infact it is generating losses in the South and Central region.So as a business manager i would focus on other tech product like copiers which is generating good profits in the regions.
# 10. Art isn't generating much profits and nor is it much in demand by the customers hence, this section should be discontinued. And the same applies to Fasteners Category.
# 11.Copiers are generating the maximum profits in the Central region but the sales is maximum in the East region, this is an area where the company could look into.
# 12. Binders are not giving much profits when compared to the heavy discounts offered by the store, hence it is suggested that the discount percentages should be lowered for binders to maximize the profits in that sector.
# 13. California and New York are the states with highest profit generating numbers, it is advisable to focus on these states more than the states generating losses such as Texas,Pennsylvania,Ohio,Tennessee,North Carolina,Illinios,Colorado,Arizona.
# 14. Texas state has the maximum discount offered by the store which is not a viable decision as it is the state generating the maximum losses for the store. The company should lower the discount rates by a high percentage to maximize or atleast stabilise the profit margin.
